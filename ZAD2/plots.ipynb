# %%
from stats import *

# %%
avg_df =  create_statistics(n = 10, m = 120, k = 5, func = lu_factorization_benchmark, name = 'lu')

# %%
avg_df
# Out:
#     size method      time    memory       add     sub       mul    div  \
# 0     10     lu  0.005444  0.020429     394.0    67.0     623.0   30.0
# 1     20     lu  0.024177  0.053872    4172.0   294.0    5272.0   80.0
# 2     30     lu  0.070052  0.114023   15308.0   629.0   17847.0  142.0
# 3     40     lu  0.153675  0.196593   38092.0  1208.0   42844.0  200.0
# 4     50     lu  0.285270  0.304008   75740.0  1887.0   83205.0  266.0
# 5     60     lu  0.503962  0.435750  134048.0  2634.0  144846.0  344.0
# 6     70     lu  0.761636  0.588437  214424.0  3645.0  229124.0  410.0
# 7     80     lu  1.178051  0.767366  325040.0  4856.0  344536.0  480.0
# 8     90     lu  1.613642  0.967515  463386.0  6243.0  487975.0  550.0
# 9    100     lu  2.200003  1.193465  641568.0  7626.0  672032.0  632.0
# 10   110     lu  2.975261  1.442871  856126.0  9173.0  892653.0  714.0
#
#             flops
# 0   206785.676475
# 1   406150.872004
# 2   484356.054060
# 3   535869.245908
# ...

# %%
plot_metric(avg_df, 'time', 'inverse')
plot_metric(avg_df, 'memory',  'inverse')
plot_metric(avg_df, 'add',  'inverse')
plot_metric(avg_df, 'sub',  'inverse')
plot_metric(avg_df, 'mul',  'inverse')
plot_metric(avg_df, 'div',  'inverse')
plot_metric(avg_df, 'flops',  'inverse')

# %%
avg_df.to_csv("lu.csv", sep=',' )

# %%
avg_g_df = pd.read_csv("gauss.csv")
avg_i_df = pd.read_csv("inversion.csv")
avg_l_df = pd.read_csv("lu.csv")

# %%
plot_metric(avg_g_df, 'time', 'gauss')
plot_metric(avg_g_df, 'memory',  'gauss')
plot_metric(avg_g_df, 'add',  'gauss')
plot_metric(avg_g_df, 'sub',  'gauss')
plot_metric(avg_g_df, 'mul',  'gauss')
plot_metric(avg_g_df, 'div',  'gauss')
plot_metric(avg_g_df, 'flops',  'gauss')

# %%
plot_metric(avg_i_df, 'time', 'inversion')
plot_metric(avg_i_df, 'memory',  'inversion')
plot_metric(avg_i_df, 'add',  'inversion')
plot_metric(avg_i_df, 'sub',  'inversion')
plot_metric(avg_i_df, 'mul',  'inversion')
plot_metric(avg_i_df, 'div',  'inversion')
plot_metric(avg_i_df, 'flops',  'inversion')

# %%
plot_metric(avg_l_df, 'time', 'lu')
plot_metric(avg_l_df, 'memory',  'lu')
plot_metric(avg_l_df, 'add',  'lu')
plot_metric(avg_l_df, 'sub',  'lu')
plot_metric(avg_l_df, 'mul',  'lu')
plot_metric(avg_l_df, 'div',  'lu')
plot_metric(avg_l_df, 'flops',  'lu')
