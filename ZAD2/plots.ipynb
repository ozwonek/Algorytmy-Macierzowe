# %%
from stats import *

# %%
avg_df =  create_statistics(n = 2, m = 20, k = 10, func = inverse_benchmark, name = 'inversion')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 avg_df =  create_statistics(n = 2, m = 20, k = 10, func = inverse_benchmark, name = 'inversion')
#
# TypeError: create_statistics() missing 1 required positional argument: 'mul'

# %%
avg_df
# Out:
#    size     method      time    memory     add   sub     mul   div  \
# 0     2  inversion  0.000391  0.002157     1.0   1.0     7.0   2.0
# 1    12  inversion  0.042408  0.028069  1594.0  74.0  1998.0  12.0
#
#           flops
# 0  29937.487775
# 1  88246.492002
